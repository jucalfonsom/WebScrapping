# %%
import requests

# %%
url = 'https://www.eltiempo.com/'

# %%
pt = requests.get(url)

# %%
pt.status_code
# Out:
# 200

# %%
print(pt.text)
# Out:
# ="simple sinFoto" dtm-name="C5" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m30440-1-30441"><div class="category-published">
# <a id="m30445-30444-30446" class="category page-link colombia colombia--otras-ciudades" href="/colombia/otras-ciudades">Otras Ciudades</a><span id="m30451-1-30452" class="published-at" published-unix="1599274760">09:59 PM</span></div>
# <h3 class="title-container" itemprop="headline">
# <a id="m30463-3-30464" class="title page-link" href="/colombia/otras-ciudades/por-segunda-vez-dimar-falla-hotel-las-americas-invade-la-playa-535795">'Hotel Las Américas invade playa y zona de manglar', insiste Dimar</a></h3>
# <meta itemprop="datePublished" content="2020-09-04"><meta itemprop="dateModified" content="2020-09-03"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/colombia/otras-ciudades/por-segunda-vez-dimar-falla-hotel-las-americas-invade-la-playa-535795"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <span itemprop="name">John Montaño</span>
# </span>
# <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
# <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>
# <meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div>
# <div class="oculto" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject"><meta itemprop="width" content="570"><meta itemprop="height" content="380"><meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg"></div></article></div>
# </section><section class="col1 secondary-small-container col-left-container"><article class="simple-image sinFoto" dtm-name="C8" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m30309-30308-30310"><div class="category-published">
# <a id="m30314-30313-30315" class="category page-link politica politica--partidos-politicos" href="/politica/partidos-politicos">Partidos Políticos</a><span id="m30320-1-30321" class="published-at" published-unix="1599255283">04:34 PM</span></div>
# <h3 class="title-container" itemprop="headline">
# <a id="m30332-3-30333" class="title page-link" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891">Así va la imagen de los presidenciables 2022</a></h3>
# <div class="epigraph-container">
# <a id="m30338-4-30339" class="epigraph page-link" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891">Sergio Fajardo, quien tiene la mejor opinión favorable entre las personas a las que se les preguntó.</a></div>
# <div class="recurso" itemtype="https://schema.org/NewsArticle">
# <figure class="image-container"><a id="m30344-5-30345" class="image page-link" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891"><img alt="Así va la imagen de los presidenciables 2022" src="..." style=" display: inline;" width="264px" height="176px" data-original="/files/image_264_176/uploads/2020/09/04/5f525d34cb994.jpeg"><meta itemprop="width" content="264"><meta itemprop="height" content="176"><meta itemprop="url" content="https://www.eltiempo.com/files/image_264_176/uploads/2020/09/04/5f525d34cb994.jpeg"></a></figure></div>
# <meta itemprop="datePublished" content="2020-09-04"><meta itemprop="dateModified" content="2020-09-04"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <span itemprop="name">Jorge Meléndez</span>
# </span>
# <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
# <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>
# <meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div>
# </article><article class="simple-image sinFoto" dtm-name="C8" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m30471-1-30472"><div class="category-published">
# <a id="m30476-30475-30477" class="category page-link justicia justicia--cortes" href="/justicia/cortes">Cortes</a><span id="m30482-1-30483" class="published-at" published-unix="1599270411">08:46 PM</span></div>
# <h3 class="title-container" itemprop="headline">
# <a id="m30494-3-30495" class="title page-link" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101">Pilotos de ‘fracking’ seguirán vigentes mientras se decide demanda</a></h3>
# <div class="epigraph-container">
# <a id="m30500-4-30501" class="epigraph page-link" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101">Corte negó suspensión  del Decreto que los autorizó, mientras se falla demanda contra la norma.<br></a></div>
# <div class="recurso" itemtype="https://schema.org/NewsArticle">
# <figure class="image-container"><a id="m30506-5-30507" class="image page-link" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101"><img alt="Detractores del ‘fracking’" src="..." style=" display: inline;" width="264px" height="176px" data-original="/files/image_264_176/uploads/2020/04/04/5e88cbdca8634.jpeg"><meta itemprop="width" content="264"><meta itemprop="height" content="176"><meta itemprop="url" content="https://www.eltiempo.com/files/image_264_176/uploads/2020/04/04/5e88cbdca8634.jpeg"></a></figure></div>
# <meta itemprop="datePublished" content="2020-09-04"><meta itemprop="dateModified" content="2020-09-04"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <span itemprop="name">María Isabel Ortiz</span>
# </span>
# <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
# <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>
# <meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div>
# </article></section><section class="col_fija col-right-container"><div class="article-simple-image-container-top">
# <article class="simple-image sinFoto" dtm-name="Contenido15" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m30353-30352-30354"><div class="category-published">
# <a id="m30358-30357-30359" class="category page-link colombia colombia--otras-ciudades" href="/colombia/otras-ciudades">Otras Ciudades</a><span id="m30364-1-30365" class="published-at" published-unix="1599189784">10:23 PM</span></div>
# <h3 class="title-container" itemprop="headline">
# <a id="m30376-3-30377" class="title page-link" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615">Los vendedores que se verían afectados por el túnel de La Línea</a></h3>
# <div class="epigraph-container">
# <a id="m30382-4-30383" class="epigraph page-link" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615">Ventas informales serían perjudicadas con apertura del corredor vial entre Calarcá y Cajamarca.<br></a></div>
# <div class="recurso" itemtype="https://schema.org/NewsArticle">
# <figure class="image-container"><a id="m30388-5-30389" class="image page-link" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615"><img alt="Túnel de La Línea" src="..." style=" display: inline;" width="264px" height="176px" data-original="/files/image_264_176/uploads/2019/11/19/5dd479ebe290d.jpeg"><meta itemprop="width" content="264"><meta itemprop="height" content="176"><meta itemprop="url" content="https://www.eltiempo.com/files/image_264_176/uploads/2019/11/19/5dd479ebe290d.jpeg"></a></figure></div>
# <meta itemprop="datePublished" content="2020-09-03"><meta itemprop="dateModified" content="2020-09-03"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
# <span itemprop="name">Laura Sepúlveda</span>
# </span>
# <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
# <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>
# <meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div>
# </article></div>
# <div class="col-right-ads-container">
# <div class="ad-container">
# <div class="module-ads">
# <div class="ad-unit" id="sas_9637" width="300" height="250"><script type="text/javascript">sas.cmd.push(function() { sas.call("std", { siteId: sas_siteId, pageId: sas_pageId, formatId: 9637, target: sas_target });});</script></div></div></div>
# </div>
# </section></div>
# </div>
#
# <div class="module-free-html">
# <div wf-module="wfed/free/ads" wf-role="ads" wf-new wf-allow="+-"></div>
# <div wf-module="wfed/free/html" wf-role="html" wf-allow="+-"></div>
# </div>
# <div class="content_grid_margin">
#
# </div>
# <div class="module-free-html">
# </div>
# </div>
# <div class="content_grid content-grid-footer">
# <footer>
# <div class="container_footer_2015">
# <div class="nivel02">
# <div class="identy-et siguenos-en-bk">
# <div class="nivel-logo2">
# <figure class="logo">
# <a href="/">
# <img src="..." alt="" data-original="/images/eltiempo_logo.png">
# </a>
# </figure>
# </div>
# <span>SÍGUENOS EN:</span>
# <ul class="redes_segir_footer">
# <li>
# <a href="https://www.facebook.com/eltiempo" target="_blank"></a>
# </li>
# <li>
# <a href="https://twitter.com/eltiempo" target="_blank"></a>
# </li>
# <li>
# <a href="https://www.instagram.com/eltiempo/" target="_blank"></a>
# </li>
# <li>
# <a href="https://www.youtube.com/user/ElTiempoPLAY" target="_blank"></a>
# </li>
# </ul>
# </div>
# <div class="nav-ft">
# <ul class="footer1-menu">
# <li class="link external first" itemprop="name">
# <a href="/ayuda" itemprop="url">AYUDA</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="/politica-privacidad" itemprop="url">AVISO DE PRIVACIDAD</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="/terminos-condiciones" itemprop="url">TÉRMINOS Y CONDICIONES</a>
# </li>
# <li class="link" itemprop="name">
# <a href="/politica-de-cookies" itemprop="url">POLÍTICA DE COOKIES</a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="/mapa-sitio" itemprop="url">MAPA DEL SITIO</a>
# </li>
# </ul>
#
# <ul class="portales">
# <li class="btn-conoce link5"><a class="btn_Texto1" href="javascript:void(0)">CONOCE NUESTROS PORTALES<span></span></a></li>
# </ul>
# </div>
# <div class="nav-ft2">
# <ul class="footer2-menu">
# <li class="link external first" itemprop="name">
# <a href="/servicio-al-cliente" itemprop="url">SERVICIO AL CLIENTE</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="https://www.ceet.co/linea-etica" itemprop="url">LÍNEA ÉTICA</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.clubvivamos.com/" itemprop="url">CLUB DE SUSCRIPTORES VIVAMOS</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="/rss" itemprop="url">RSS</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="https://cursoscortos.eltiempo.com/" itemprop="url">CURSOS EL TIEMPO</a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="https://www.ceet.co/" itemprop="url">CASA EDITORIAL EL TIEMPO</a>
# </li>
# </ul>
#
# </div>
# <div class="nav02-ft">
# <div class="subnivel01">
# <ul class="footer3-menu">
# <li class="link external first" itemprop="name">
# <a href="https://tienda.eltiempo.com/" itemprop="url">COLECCIONES EL TIEMPO</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="https://www.ceet.co/" itemprop="url">PAUTE CON NOSOTROS</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.elempleo.com/sitios-empresariales/colombia/el-tiempo-casa-editorial/" itemprop="url">TRABAJE CON NOSOTROS</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="/publicidad-politica-pagada" itemprop="url">PUBLICIDAD POLÍTICA PAGADA</a>
# </li>
# <li class="link external" itemprop="name">
# <a href="https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital?utm_source=Autopauta&amp;utm_medium=eltiempo_prp&amp;utm_campaign=AutoPautaFija&amp;utm_content=BotonHomeFooter" itemprop="url">SUSCRIBIRSE</a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="https://www.ceet.co/solicitud-reversion-de-pago" itemprop="url">REVERSIÓN DE PAGO</a>
# </li>
# </ul>
#
# </div>
# </div>
# <div class="miembro">
# <div class="member-of-container">
# <div class="span-container">
# <span class="miembro-title">MIEMBRO DE:</span>
# </div>
# <ul class="group-members">
# <li><figure><img src="/images/footer/img_1.png" alt=""></figure></a></figure><span>Grupo de Diarios de América</span></li>
# <li><a href='https://ami.org.co/' target='_blank'><figure><img src="/images/footer/img_3.png" alt=""></figure></a><span><a href='https://ami.org.co/' target='_blank'>Asociación Colombiana de Medios de Información</a></span></li>
# <li><figure><img src="/images/footer/img_2.png" alt=""></figure><span>Interactive Advertisement Bureau</span></li>
# <li><figure><img src="/images/footer/img_4.png" alt=""></figure><span>Superintendencia de Industria y Comercio</span></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="subnnivel_desplegado">
# <div class="subnivel02">
# <ul class="footer-portals1-menu">
# <li class="link external first" itemprop="name">
# <a href="http://portafolio.co" itemprop="url">Noticias de economía<span> - portafolio.co</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.elempleo.com/co/ofertas-empleo/" itemprop="url">Empleos en Colombia<span> - elempleo.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.futbolred.com" itemprop="url">Noticias de fútbol<span> - futbolred.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.carroya.com" itemprop="url">Venta de Carros<span> - carroya.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.revistadonjuan.com" itemprop="url">Fotos y modelos<span> - revistadonjuan.com</span></a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="http://www.diarioadn.co" itemprop="url">Noticias de Actualidad<span> - diarioadn.co</a>
# </li>
# </ul>
#
# <ul class="footer-portals2-menu">
# <li class="link external first" itemprop="name">
# <a href="http://www.metrocuadrado.com" itemprop="url">Finca raíz en Colombia<span> - metrocuadrado.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.abcdelbebe.com" itemprop="url">Embarazo<span> - abcdelbebe.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.alo.co" itemprop="url">Mujer profesional<span> - alo.co</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.motor.com.co" itemprop="url">Noticias de vehículos<span> - motor.com.co</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://www.guiaacademica.com/asesora/" itemprop="url">Asesoría en Posgrados<span> - guiaacademica.com</span></a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="http://www.e-hunters.com" itemprop="url">Head hunters<span> - e-hunters.com</span></a>
# </li>
# </ul>
#
# <ul class="footer-portals3-menu">
# <li class="link external first" itemprop="name">
# <a href="http://www.audienciadigital.co/" itemprop="url">Paute en internet<span> - audienciadigital.co</span></a>
# </li>
# <li class="eltiempo-television" itemprop="name">
# <a href="/eltiempo-television" itemprop="url">Noticias 24 horas<span> - canaleltiempo.tv</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://clasificados.eltiempo.com" itemprop="url">Clasificados<span> - clasificados.eltiempo.com</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://citytv.com.co/" itemprop="url">Videos de entretenimiento<span> - citytv.com.co</span></a>
# </li>
# <li class="link external" itemprop="name">
# <a href="http://blackfriday.loencontraste.com/" itemprop="url">Black Friday<span> - Loencontraste.com</span></a>
# </li>
# <li class="link external last" itemprop="name">
# <a href="https://www.canchasfutbolred.com/" itemprop="url">Reserva de Canchas de Fútbol<span> - canchasfutbolred.com</span></a>
# </li>
# </ul>
#
# </div>
# </div>
# <div class="nivel03">
# <div class="disclaimer-ft">
# <div class="disclaimer-content">
# <p id="p18613-m388-387-389">COPYRIGHT © 2020 EL TIEMPO Casa Editorial. Prohibida su reproducción total o parcial, así como su traducción a cualquier idioma sin autorización escrita de su titular.<br>ELTIEMPO.com todas las noticias principales de Colombia y el Mundo</p></div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <div class="dictum-box" id="dictum-box"></div>
# </div>
# <script type="text/javascript">
# var sas_pageId = "152163";
# </script>
# <script defer="defer" src="//ced.sascdn.com/tag/484/smart.js" type="text/javascript"></script>
# <script type='text/javascript'>
# /** CONFIGURATION START **/
# _sf_async_config.sections = 'home'; //CHANGE THIS
# _sf_async_config.authors = ''; //CHANGE THIS
# var _cbq = window._cbq = (window._cbq || []);
# if(getUserName()){
# if(getCmsCookie('suscriptor') == "true"){
# _cbq.push(['_acct', 'paid']);
# }else
# _cbq.push(['_acct', 'lgdin']);
# }
# else{
# _cbq.push(['_acct', 'anon']);
# }
# /** CONFIGURATION END **/
# (function() {
# function loadChartbeat() {
# var e = document.createElement('script');
# var n = document.getElementsByTagName('script')[0];
# e.type = 'text/javascript';
# e.async = true;
# e.src = '//static.chartbeat.com/js/chartbeat.js';
# n.parentNode.insertBefore(e, n);
# }
# loadChartbeat();
# })();
# </script>
# <!-- begin Convert Experiences code-->
# <!-- <script defer="defer" type="text/javascript" src="//cdn-3.convertexperiments.com/js/10022306-10021161.js"></script>-->
# <!-- end Convert Experiences code -->
# <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" defer="defer"></script>
# <script async type="text/javascript" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&ns=1&cb=625280408"></script>
# </body>
# </html>

# %%
pt.content
# Out:
# ePublished" content="2020-09-04"><meta itemprop="dateModified" content="2020-09-03"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/colombia/otras-ciudades/por-segunda-vez-dimar-falla-hotel-las-americas-invade-la-playa-535795"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">\n<span itemprop="name">John Monta\xc3\xb1o</span>\n</span>\n<div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">\n<div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">\n<meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>\n<meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div>\n<div class="oculto" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject"><meta itemprop="width" content="570"><meta itemprop="height" content="380"><meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg"></div></article></div>\n</section><section class="col1 secondary-small-container col-left-container"><article class="simple-image sinFoto" dtm-name="C8" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m30309-30308-30310"><div class="category-published">\n<a id="m30314-30313-30315" class="category page-link politica politica--partidos-politicos" href="/politica/partidos-politicos">Partidos Pol\xc3\xadticos</a><span id="m30320-1-30321" class="published-at" published-unix="1599255283">04:34 PM</span></div>\n<h3 class="title-container" itemprop="headline">\n<a id="m30332-3-30333" class="title page-link" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891">As\xc3\xad va la imagen de los presidenciables 2022</a></h3>\n<div class="epigraph-container">\n<a id="m30338-4-30339" class="epigraph page-link" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891">Sergio Fajardo, quien tiene la mejor opini\xc3\xb3n favorable entre las personas a las que se les pregunt\xc3\xb3.</a></div>\n<div class="recurso" itemtype="https://schema.org/NewsArticle">\n<figure class="image-container"><a id="m30344-5-30345" class="image page-link" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject" href="/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891"><img alt="As\xc3\xad va la imagen de los presidenciables 2022" src="..." style=" display: inline;" width="264px" height="176px" data-original="/files/image_264_176/uploads/2020/09/04/5f525d34cb994.jpeg"><meta itemprop="width" content="264"><meta itemprop="height" content="176"><meta itemprop="url" content="https://www.eltiempo.com/files/image_264_176/uploads/2020/09/04/5f525d34cb994.jpeg"></a></figure></div>\n<meta itemprop="datePublished" content="2020-09-04"><meta itemprop="dateModified" content="2020-09-04"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/politica/partidos-politicos/encuesta-gallup-asi-va-la-imagen-de-los-presidenciables-para-2022-535891"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">\n<span itemprop="name">Jorge Mel\xc3\xa9ndez</span>\n</span>\n<div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">\n<div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">\n<meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg"><meta itemprop="width" content="600"><meta itemprop="height" content="60"></div>\n<meta itemprop="name" content="EL TIEMPO"><meta itemprop="url" content="https://www.eltiempo.com"></div> ...

# %%
pt.headers
# Out:
# {'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'X-Server': 'fet01', 'Strict-Transport-Security': 'max-age=15768000; includeSubDomains, max-age=157680000', 'x-url': '/', 'x-frame-options': 'sameorigin', 'X-Cacheable': 'YES', 'X-Varnish': '227972020 227859768', 'X-sc': 'fetx1', 'X-CDN': 'Incapsula', 'Content-Encoding': 'gzip', 'X-Iinfo': '10-160000378-160204402 SNYy RT(1599331134725 1284344) q(0 0 0 1) r(0 0) U5', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,1', 'Cache-Control': 'max-age=120', 'Expires': 'Sat, 05 Sep 2020 19:05:52 GMT', 'Date': 'Sat, 05 Sep 2020 19:03:52 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Vary': 'Accept-Encoding', 'Server-Timing': 'cdn-cache; desc=HIT, edge; dur=1', 'version': 'desktop'}

# %%
pt.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
pt.request.method
# Out:
# 'GET'

# %%
pt.request.url
# Out:
# 'https://www.eltiempo.com/'

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(pt.text, 'lxml')

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# ry page-link justicia justicia--cortes" href="/justicia/cortes" id="m30476-30475-30477">
#           Cortes
#          </a>
#          <span class="published-at" id="m30482-1-30483" published-unix="1599270411">
#           08:46 PM
#          </span>
#         </div>
#         <h3 class="title-container" itemprop="headline">
#          <a class="title page-link" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101" id="m30494-3-30495">
#           Pilotos de ‘fracking’ seguirán vigentes mientras se decide demanda
#          </a>
#         </h3>
#         <div class="epigraph-container">
#          <a class="epigraph page-link" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101" id="m30500-4-30501">
#           Corte negó suspensión  del Decreto que los autorizó, mientras se falla demanda contra la norma.
#           <br/>
#          </a>
#         </div>
#         <div class="recurso" itemtype="https://schema.org/NewsArticle">
#          <figure class="image-container">
#           <a class="image page-link" href="/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101" id="m30506-5-30507" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#            <img alt="Detractores del ‘fracking’" data-original="/files/image_264_176/uploads/2020/04/04/5e88cbdca8634.jpeg" height="176px" src="..." style=" display: inline;" width="264px"/>
#            <meta content="264" itemprop="width"/>
#            <meta content="176" itemprop="height"/>
#            <meta content="https://www.eltiempo.com/files/image_264_176/uploads/2020/04/04/5e88cbdca8634.jpeg" itemprop="url"/>
#           </a>
#          </figure>
#         </div>
#         <meta content="2020-09-04" itemprop="datePublished"/>
#         <meta content="2020-09-04" itemprop="dateModified"/>
#         <meta itemid="https://www.eltiempo.com/justicia/cortes/decreto-sobre-pilotos-de-fracking-seguira-vigente-mientras-se-estudia-demanda-536101" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"/>
#         <span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#          <span itemprop="name">
#           María Isabel Ortiz
#          </span>
#         </span>
#         <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#          <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#           <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg" itemprop="url"/>
#           <meta content="600" itemprop="width"/>
#           <meta content="60" itemprop="height"/>
#          </div>
#          <meta content="EL TIEMPO" itemprop="name"/>
#          <meta content="https://www.eltiempo.com" itemprop="url"/>
#         </div>
#        </article>
#       </section>
#       <section class="col_fija col-right-container">
#        <div class="article-simple-image-container-top">
#         <article class="simple-image sinFoto" dtm-name="Contenido15" id="p100498-m30353-30352-30354" itemscope="" itemtype="https://schema.org/NewsArticle">
#          <div class="category-published">
#           <a class="category page-link colombia colombia--otras-ciudades" href="/colombia/otras-ciudades" id="m30358-30357-30359">
#            Otras Ciudades
#           </a>
#           <span class="published-at" id="m30364-1-30365" published-unix="1599189784">
#            10:23 PM
#           </span>
#          </div>
#          <h3 class="title-container" itemprop="headline">
#           <a class="title page-link" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615" id="m30376-3-30377">
#            Los vendedores que se verían afectados por el túnel de La Línea
#           </a>
#          </h3>
#          <div class="epigraph-container">
#           <a class="epigraph page-link" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615" id="m30382-4-30383">
#            Ventas informales serían perjudicadas con apertura del corredor vial entre Calarcá y Cajamarca.
#            <br/>
#           </a>
#          </div>
#          <div class="recurso" itemtype="https://schema.org/NewsArticle">
#           <figure class="image-container">
#            <a class="image page-link" href="/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615" id="m30388-5-30389" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#             <img alt="Túnel de La Línea" data-original="/files/image_264_176/uploads/2019/11/19/5dd479ebe290d.jpeg" height="176px" src="..." style=" display: inline;" width="264px"/>
#             <meta content="264" itemprop="width"/>
#             <meta content="176" itemprop="height"/>
#             <meta content="https://www.eltiempo.com/files/image_264_176/uploads/2019/11/19/5dd479ebe290d.jpeg" itemprop="url"/>
#            </a>
#           </figure>
#          </div>
#          <meta content="2020-09-03" itemprop="datePublished"/>
#          <meta content="2020-09-03" itemprop="dateModified"/>
#          <meta itemid="https://www.eltiempo.com/colombia/otras-ciudades/tunel-de-la-linea-vendedores-ambulantes-afectados-por-las-obras-en-cajamarca-535615" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"/>
#          <span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#           <span itemprop="name">
#            Laura Sepúlveda
#           </span>
#          </span>
#          <div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#           <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#            <meta content="https://www.eltiempo.com/bundles/eltiempocms/images/el-tiempo/logo-el-tiempo-azul.jpg" itemprop="url"/>
#            <meta content="600" itemprop="width"/>
#            <meta content="60" itemprop="height"/>
#           </div>
#           <meta content="EL TIEMPO" itemprop="name"/>
#           <meta content="https://www.eltiempo.com" itemprop="url"/>
#          </div>
#         </article>
#        </div>
#        <div class="col-right-ads-container">
#         <div class="ad-container">
#          <div class="module-ads">
#           <div class="ad-unit" height="250" id="sas_9637" width="300">
#            <script type="text/javascript">
#             sas.cmd.push(function() { sas.call("std", { siteId: sas_siteId, pageId: sas_pageId, formatId: 9637, target: sas_target });});
#            </script>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <div class="module-free-html">
#      <div wf-allow="+-" wf-module="wfed/free/ads" wf-new="" wf-role="ads">
#      </div>
#      <div wf-allow="+-" wf-module="wfed/free/html" wf-role="html">
#      </div>
#     </div>
#     <div class="content_grid_margin">
#     </div>
#     <div class="module-free-html">
#     </div>
#    </div>
#    <div class="content_grid content-grid-footer">
#     <footer>
#      <div class="container_footer_2015">
#       <div class="nivel02">
#        <div class="identy-et siguenos-en-bk">
#         <div class="nivel-logo2">
#          <figure class="logo">
#           <a href="/">
#            <img alt="" data-original="/images/eltiempo_logo.png" src="..."/>
#           </a>
#          </figure>
#         </div>
#         <span>
#          SÍGUENOS EN:
#         </span>
#         <ul class="redes_segir_footer">
#          <li>
#           <a href="https://www.facebook.com/eltiempo" target="_blank">
#           </a>
#          </li>
#          <li>
#           <a href="https://twitter.com/eltiempo" target="_blank">
#           </a>
#          </li>
#          <li>
#           <a href="https://www.instagram.com/eltiempo/" target="_blank">
#           </a>
#          </li>
#          <li>
#           <a href="https://www.youtube.com/user/ElTiempoPLAY" target="_blank">
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="nav-ft">
#         <ul class="footer1-menu">
#          <li class="link external first" itemprop="name">
#           <a href="/ayuda" itemprop="url">
#            AYUDA
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="/politica-privacidad" itemprop="url">
#            AVISO DE PRIVACIDAD
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="/terminos-condiciones" itemprop="url">
#            TÉRMINOS Y CONDICIONES
#           </a>
#          </li>
#          <li class="link" itemprop="name">
#           <a href="/politica-de-cookies" itemprop="url">
#            POLÍTICA DE COOKIES
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="/mapa-sitio" itemprop="url">
#            MAPA DEL SITIO
#           </a>
#          </li>
#         </ul>
#         <ul class="portales">
#          <li class="btn-conoce link5">
#           <a class="btn_Texto1" href="javascript:void(0)">
#            CONOCE NUESTROS PORTALES
#            <span>
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="nav-ft2">
#         <ul class="footer2-menu">
#          <li class="link external first" itemprop="name">
#           <a href="/servicio-al-cliente" itemprop="url">
#            SERVICIO AL CLIENTE
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="https://www.ceet.co/linea-etica" itemprop="url">
#            LÍNEA ÉTICA
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.clubvivamos.com/" itemprop="url">
#            CLUB DE SUSCRIPTORES VIVAMOS
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="/rss" itemprop="url">
#            RSS
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="https://cursoscortos.eltiempo.com/" itemprop="url">
#            CURSOS EL TIEMPO
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="https://www.ceet.co/" itemprop="url">
#            CASA EDITORIAL EL TIEMPO
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="nav02-ft">
#         <div class="subnivel01">
#          <ul class="footer3-menu">
#           <li class="link external first" itemprop="name">
#            <a href="https://tienda.eltiempo.com/" itemprop="url">
#             COLECCIONES EL TIEMPO
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://www.ceet.co/" itemprop="url">
#             PAUTE CON NOSOTROS
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="http://www.elempleo.com/sitios-empresariales/colombia/el-tiempo-casa-editorial/" itemprop="url">
#             TRABAJE CON NOSOTROS
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="/publicidad-politica-pagada" itemprop="url">
#             PUBLICIDAD POLÍTICA PAGADA
#            </a>
#           </li>
#           <li class="link external" itemprop="name">
#            <a href="https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital?utm_source=Autopauta&amp;utm_medium=eltiempo_prp&amp;utm_campaign=AutoPautaFija&amp;utm_content=BotonHomeFooter" itemprop="url">
#             SUSCRIBIRSE
#            </a>
#           </li>
#           <li class="link external last" itemprop="name">
#            <a href="https://www.ceet.co/solicitud-reversion-de-pago" itemprop="url">
#             REVERSIÓN DE PAGO
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="miembro">
#         <div class="member-of-container">
#          <div class="span-container">
#           <span class="miembro-title">
#            MIEMBRO DE:
#           </span>
#          </div>
#          <ul class="group-members">
#           <li>
#            <figure>
#             <img alt="" src="/images/footer/img_1.png"/>
#            </figure>
#            <span>
#             Grupo de Diarios de América
#            </span>
#           </li>
#           <li>
#            <a href="https://ami.org.co/" target="_blank">
#             <figure>
#              <img alt="" src="/images/footer/img_3.png"/>
#             </figure>
#            </a>
#            <span>
#             <a href="https://ami.org.co/" target="_blank">
#              Asociación Colombiana de Medios de Información
#             </a>
#            </span>
#           </li>
#           <li>
#            <figure>
#             <img alt="" src="/images/footer/img_2.png"/>
#            </figure>
#            <span>
#             Interactive Advertisement Bureau
#            </span>
#           </li>
#           <li>
#            <figure>
#             <img alt="" src="/images/footer/img_4.png"/>
#            </figure>
#            <span>
#             Superintendencia de Industria y Comercio
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="subnnivel_desplegado">
#        <div class="subnivel02">
#         <ul class="footer-portals1-menu">
#          <li class="link external first" itemprop="name">
#           <a href="http://portafolio.co" itemprop="url">
#            Noticias de economía
#            <span>
#             - portafolio.co
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.elempleo.com/co/ofertas-empleo/" itemprop="url">
#            Empleos en Colombia
#            <span>
#             - elempleo.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.futbolred.com" itemprop="url">
#            Noticias de fútbol
#            <span>
#             - futbolred.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.carroya.com" itemprop="url">
#            Venta de Carros
#            <span>
#             - carroya.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.revistadonjuan.com" itemprop="url">
#            Fotos y modelos
#            <span>
#             - revistadonjuan.com
#            </span>
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="http://www.diarioadn.co" itemprop="url">
#            Noticias de Actualidad
#            <span>
#             - diarioadn.co
#            </span>
#           </a>
#          </li>
#         </ul>
#         <ul class="footer-portals2-menu">
#          <li class="link external first" itemprop="name">
#           <a href="http://www.metrocuadrado.com" itemprop="url">
#            Finca raíz en Colombia
#            <span>
#             - metrocuadrado.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.abcdelbebe.com" itemprop="url">
#            Embarazo
#            <span>
#             - abcdelbebe.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.alo.co" itemprop="url">
#            Mujer profesional
#            <span>
#             - alo.co
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.motor.com.co" itemprop="url">
#            Noticias de vehículos
#            <span>
#             - motor.com.co
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://www.guiaacademica.com/asesora/" itemprop="url">
#            Asesoría en Posgrados
#            <span>
#             - guiaacademica.com
#            </span>
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="http://www.e-hunters.com" itemprop="url">
#            Head hunters
#            <span>
#             - e-hunters.com
#            </span>
#           </a>
#          </li>
#         </ul>
#         <ul class="footer-portals3-menu">
#          <li class="link external first" itemprop="name">
#           <a href="http://www.audienciadigital.co/" itemprop="url">
#            Paute en internet
#            <span>
#             - audienciadigital.co
#            </span>
#           </a>
#          </li>
#          <li class="eltiempo-television" itemprop="name">
#           <a href="/eltiempo-television" itemprop="url">
#            Noticias 24 horas
#            <span>
#             - canaleltiempo.tv
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://clasificados.eltiempo.com" itemprop="url">
#            Clasificados
#            <span>
#             - clasificados.eltiempo.com
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://citytv.com.co/" itemprop="url">
#            Videos de entretenimiento
#            <span>
#             - citytv.com.co
#            </span>
#           </a>
#          </li>
#          <li class="link external" itemprop="name">
#           <a href="http://blackfriday.loencontraste.com/" itemprop="url">
#            Black Friday
#            <span>
#             - Loencontraste.com
#            </span>
#           </a>
#          </li>
#          <li class="link external last" itemprop="name">
#           <a href="https://www.canchasfutbolred.com/" itemprop="url">
#            Reserva de Canchas de Fútbol
#            <span>
#             - canchasfutbolred.com
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="nivel03">
#        <div class="disclaimer-ft">
#         <div class="disclaimer-content">
#          <p id="p18613-m388-387-389">
#           COPYRIGHT © 2020 EL TIEMPO Casa Editorial. Prohibida su reproducción total o parcial, así como su traducción a cualquier idioma sin autorización escrita de su titular.
#           <br/>
#           ELTIEMPO.com todas las noticias principales de Colombia y el Mundo
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div class="dictum-box" id="dictum-box">
#    </div>
#   </div>
#   <script type="text/javascript">
#    var sas_pageId = "152163";
#   </script>
#   <script defer="defer" src="//ced.sascdn.com/tag/484/smart.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /** CONFIGURATION START **/
# _sf_async_config.sections = 'home'; //CHANGE THIS
# _sf_async_config.authors = ''; //CHANGE THIS
# var _cbq = window._cbq = (window._cbq || []);
# if(getUserName()){
# if(getCmsCookie('suscriptor') == "true"){
# _cbq.push(['_acct', 'paid']);
# }else
# _cbq.push(['_acct', 'lgdin']);
# }
# else{
# _cbq.push(['_acct', 'anon']);
# }
# /** CONFIGURATION END **/
# (function() {
# function loadChartbeat() {
# var e = document.createElement('script');
# var n = document.getElementsByTagName('script')[0];
# e.type = 'text/javascript';
# e.async = true;
# e.src = '//static.chartbeat.com/js/chartbeat.js';
# n.parentNode.insertBefore(e, n);
# }
# loadChartbeat();
# })();
#   </script>
#   <!-- begin Convert Experiences code-->
#   <!-- <script defer="defer" type="text/javascript" src="//cdn-3.convertexperiments.com/js/10022306-10021161.js"></script>-->
#   <!-- end Convert Experiences code -->
#   <script defer="defer" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=1&amp;cb=625280408" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
noticias = s.find_all('a', attrs={'class':'title page-link'})

# %%
noticia = noticias[0]
noticia
# Out:
# <a class="title page-link" href="/podcast/el-primer-cafe/principales-noticias-de-colombia-y-el-mundo-en-el-primer-cafe-535910" id="m511-1-512">El fiscal asignado al caso Uribe / El reino de la pastora Piraquive</a>

# %%
noticia.get('href')
# Out:
# '/podcast/el-primer-cafe/principales-noticias-de-colombia-y-el-mundo-en-el-primer-cafe-535910'

# %%
noticia.get_text()
# Out:
# 'El fiscal asignado al caso Uribe / El reino de la pastora Piraquive'

# %%
nombre_noticias = [noticia.get_text() for noticia in noticias]

# %%
links_noticias = [noticia.get('href') for noticia in noticias]
