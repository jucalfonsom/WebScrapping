# %%
import requests

# %%
url = 'https://www.eltiempo.com/'

# %%
pt = requests.get(url)

# %%
pt.status_code
# Out:
# 200

# %%
print(pt.text)
# Out:
# pe="https://schema.org/ImageObject"><meta itemprop="width" content="570"><meta itemprop="height" content="380"><meta itemprop="url" content="https://www.eltiempo.com/bundles/eltiempocms/images/default.jpg"></div></article><article class="simple sinFoto" dtm-name="C5" itemscope="" itemtype="https://schema.org/NewsArticle" id="p100498-m10716-1-10717"><div class="category-published">
# <a id="m10721-10720-10722" class="category page-link justicia justicia--servicios" href="/justicia/servicios">Servicios</a><span id="m10727-1-10728" class="published-at" published-unix="1599286208">01:10 AM</span></div>
# <h3 class="title-container" itemprop="headline">
# <a id="m10739-3-10740" class="title page-link" href="/justicia/servicios/tunel-de-la-linea-top-10-de-megaobras-mas-grandes-de-colombia-536036">Túnel de La Línea y el ‘top 10’ de megaobras más grandes de Colombia</a></h3>
# ...

# %%
pt.content
# Out:
# emprop="headline">\n<a id="m10739-3-10740" class="title page-link" href="/justicia/servicios/tunel-de-la-linea-top-10-de-megaobras-mas-grandes-de-colombia-536036">T\xc3\xbanel de La L\xc3\xadnea y el \xe2\x80\x98top 10\xe2\x80\x99 de megaobras m\xc3\xa1s grandes de Colombia</a></h3>\n<meta itemprop="datePublished" content="2020-09-05"><meta itemprop="dateModified" content="2020-09-04"><meta itemscope="" itemprop="mainEntityOfPage" itemtype="https://schema.org/WebPage" itemid="https://www.eltiempo.com/justicia/servicios/tunel-de-la-linea-top-10-de-megaobras-mas-grandes-de-colombia-536036"><span class="oculto" itemprop="author" itemscope="" itemtype="https://schema.org/Person">\n<span itemprop="name">Laura Estefania Leon Arroyave</span>\n</span>\n<div class="oculto" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">\n<div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">\n<meta itemprop="url" content="https://www.eltiempo.com/bundles/elt
# ...

# %%
pt.headers
# Out:
# {'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'X-Server': 'fet01', 'Strict-Transport-Security': 'max-age=15768000; includeSubDomains, max-age=157680000', 'x-url': '/', 'x-frame-options': 'sameorigin', 'X-Cacheable': 'YES', 'X-Varnish': '214163798 226455986', 'X-sc': 'fetx1', 'X-CDN': 'Incapsula', 'Content-Encoding': 'gzip', 'X-Iinfo': '12-114478755-114518317 SNYN RT(1599425027188 417472) q(0 0 0 1) r(0 0) U5', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,1', 'Cache-Control': 'max-age=120', 'Expires': 'Sun, 06 Sep 2020 20:54:51 GMT', 'Date': 'Sun, 06 Sep 2020 20:52:51 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Vary': 'Accept-Encoding', 'Server-Timing': 'cdn-cache; desc=HIT, edge; dur=1', 'version': 'desktop'}

# %%
pt.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
pt.request.method
# Out:
# 'GET'

# %%
pt.request.url
# Out:
# 'https://www.eltiempo.com/'

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(pt.text, 'lxml')

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# tps://www.eltiempo.com" itemprop="url"/>
#         </div>
#        </article>
#        <article class="simple-image sinFoto" dtm-name="C8" id="p100498-m10747-1-10748" itemscope="" itemtype="https://schema.org/NewsArticle">
#         <div class="category-published">
#          <a class="category page-link politica politica--gobierno" href="/politica/gobierno" id="m10752-10751-10753">
#           Gobierno
#          </a>
#          <span class="published-at" id="m10758-1-10759" published-unix="1599369753">
#           12:22 AM
#          </span>
#         </div>
#         <h3 class="title-container" itemprop="headline">
#          <a class="title page-link" href="/politica/gobierno/noticias-de-hoy-proximos-cambios-en-los-ministerios-alicia-arango-y-fernado-carrillo-536245" id="m10770-3-10771">
#           En secreto... ¿Qué hará el procurador Carrillo cuando deje el cargo?
#          </a>
#         </h3>
#         <div class="epigraph-container">
# ...

# %%
noticias = s.find_all('a', attrs={'class':'title page-link'})

# %%
noticia = noticias[0]
noticia
# Out:
# <a class="title page-link" href="/tecnosfera/tutoriales-tecnologia/como-tener-una-mejor-conexion-a-internet-en-la-casa-536158" id="m511-1-512">Diez cosas a tener en cuenta para mejorar su conexión a internet</a>

# %%
noticia.get('href')
# Out:
# '/tecnosfera/tutoriales-tecnologia/como-tener-una-mejor-conexion-a-internet-en-la-casa-536158'

# %%
noticia.get_text()
# Out:
# 'Diez cosas a tener en cuenta para mejorar su conexión a internet'

# %%
nombre_noticias = [noticia.get_text() for noticia in noticias]

# %%
links_noticias = [noticia.get('href') for noticia in noticias]
